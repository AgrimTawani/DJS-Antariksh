# %% [markdown]
# # Linear Regression using Scikit-learn

# %%
import pandas as pd
import matplotlib.pyplot as plt  
from sklearn.model_selection import train_test_split
diamond_data = pd.read_csv('Diamond.csv')
X = diamond_data['carat']
y = diamond_data['price']
my_df = diamond_data[['carat', 'price']]
my_df
# Out:
#        carat  price
# 0       0.23    326
# 1       0.21    326
# 2       0.23    327
# 3       0.29    334
# 4       0.31    335
# ...      ...    ...
# 53935   0.72   2757
# 53936   0.72   2757
# 53937   0.70   2757
# 53938   0.86   2757
# 53939   0.75   2757
#
# [53940 rows x 2 columns]

# %%
plt.figure(figsize=(12, 8))
plt.scatter(X,y,alpha=0.3)

# %% [markdown]
# Spliting the dataset 30% for training the model and rest for testing our model

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
print(X_train)
print(" ")
print(y_train)
# Out:
# 241      1.01
# 17398    0.32
# 36608    0.34
# 44731    0.56
# 18104    1.02
#          ...
# 11284    1.05
# 44732    0.47
# 38158    0.33
# 860      0.90
# 15795    1.14
# Name: carat, Length: 36139, dtype: float64
#
# 241      2788
# 17398     612
# 36608     477
# 44731    1616
# 18104    7324
#          ...
# 11284    4975
# 44732    1617
# 38158    1014
# 860      2871
# 15795    6320
# Name: price, Length: 36139, dtype: int64

# %% [markdown]
# - The above data is one dimensional
# - sklearn only takes two dimensional data
# - hence converting this data to two dimensional

# %%
import numpy as np  
X_train = np.array(X_train).reshape(-1, 1)
X_test= np.array(X_test).reshape(-1, 1)
y_train = np.array(y_train).reshape(-1, 1)
y_test= np.array(y_test).reshape(-1, 1)

# %% [markdown]
# Applying linear regression method

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# m = x coefficient , c = y intercept => Y = mX + c
m, c = lr.coef_, lr.intercept_ 
m, c
# Out:
# (array([[7770.34601788]]), array([-2261.15798078]))

# %%
Y_predicted = lr.predict(X_test)

plt.scatter(X_test, y_test)
plt.plot(X_test, Y_predicted, color="red")
plt.xlabel("Carat")
plt.ylabel("Prices")
# Out:
# Text(0, 0.5, 'Prices')
